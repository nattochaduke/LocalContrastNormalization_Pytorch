# %%
import numpy as np
import torch
import torch.nn.functional as F
from torch import Tensor
import torchvision.transforms

from PIL import Image
from scipy.ndimage.filters import convolve

# %%
class LocalContrastNormalization(object):
    """
    Conduct a local contrast normalization algorithm by
    Pinto, N., Cox, D. D., and DiCarlo, J. J. (2008). Why is real-world visual object recognition hard?
     PLoS Comput Biol , 4 . 456 (they called this "Local input divisive normalization")

    the kernel size is controllable by argument kernel_size.
    """
    def __init__(self, kernel_size=3, mode='constant', cval=0.0):
        """

        :param kernel_size: int, kernel(window) size.
        :param mode: {'reflect', 'constant', 'nearest', 'mirror', 'warp'}, optional
                        determines how the array borders are handled. The meanings are listed in
                        https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.ndimage.filters.convolve.html
                        default is 'constant' as 0, different from the scipy default.

        """
        self.kernel_size = kernel_size
        self.mode = mode
        self.cval = cval

    def __call__(self, tensor):
        """

        :param tensor: Tensor image os size (C, H, W) to be normalized.
        :return:
            Tensor: Normalized Tensor image, in size (C, H, W).
        """
        C, H, W = tensor.size()
        kernel = np.ones((self.kernel_size, self.kernel_size))

        arr = np.array(tensor)
        local_sum_arr = np.array([convolve(arr[c], kernel, mode=self.mode, cval=self.cval)
                                  for c in range(C)]) # An array that has shape(C, H, W)
                                                      # Each element [c, h, w] is the summation of the values
                                                      # in the window that has arr[c,h,w] at the center.
        local_avg_arr = local_sum_arr / (self.kernel_size**2) # The tensor of local averages.

        arr_square = np.square(arr)
        local_sum_arr_square = np.array([convolve(arr_square[c], kernel, mode=self.mode, cval=self.cval)
                                  for c in range(C)]) # An array that has shape(C, H, W)
                                                      # Each element [c, h, w] is the summation of the values
                                                      # in the window that has arr_square[c,h,w] at the center.
        local_norm_arr = np.sqrt(local_sum_arr_square) # The tensor of local Euclidean norms.


        local_avg_divided_by_norm = local_avg_arr / (1e-8+local_norm_arr)

        result_arr = np.minimum(local_avg_arr, local_avg_divided_by_norm)
        return torch.Tensor(result_arr)



    def __repr__(self):
        return self.__class__.__name__ + '(kernel_size={0}, threshold={1})'.format(self.kernel_size, self.threshold)

# %%
lcn = LocalContrastNormalization()

# %%
tensor = Tensor(np.arange(400).reshape(4, 10, 10)) / 400

# %%
tensor[0]
# Out:
#  0.0000  0.0025  0.0050  0.0075  0.0100  0.0125  0.0150  0.0175  0.0200  0.0225
#  0.0250  0.0275  0.0300  0.0325  0.0350  0.0375  0.0400  0.0425  0.0450  0.0475
#  0.0500  0.0525  0.0550  0.0575  0.0600  0.0625  0.0650  0.0675  0.0700  0.0725
#  0.0750  0.0775  0.0800  0.0825  0.0850  0.0875  0.0900  0.0925  0.0950  0.0975
#  0.1000  0.1025  0.1050  0.1075  0.1100  0.1125  0.1150  0.1175  0.1200  0.1225
#  0.1250  0.1275  0.1300  0.1325  0.1350  0.1375  0.1400  0.1425  0.1450  0.1475
#  0.1500  0.1525  0.1550  0.1575  0.1600  0.1625  0.1650  0.1675  0.1700  0.1725
#  0.1750  0.1775  0.1800  0.1825  0.1850  0.1875  0.1900  0.1925  0.1950  0.1975
#  0.2000  0.2025  0.2050  0.2075  0.2100  0.2125  0.2150  0.2175  0.2200  0.2225
#  0.2250  0.2275  0.2300  0.2325  0.2350  0.2375  0.2400  0.2425  0.2450  0.2475
# [torch.FloatTensor of size 10x10]

# %%
print('*'*100)
print('calculating the result of lcn(tensor)[0][3][3] by hand.')
ls = [tensor[0][i][j] for i in [2, 3, 4] for j in [2, 3, 4]]
print("the values around tensor[0][3][3] is {}".format(ls))
print("the average is {}".format(np.average(ls)))
print("the Euclidean norm is {} < 1".format(np.sqrt(np.sum(np.square(ls)))))
print("Thus the resulting value of lcn(tensor)[0][3][3] must be {} and the result is {}".format(np.average(ls), lcn(tensor)[0][3][3]))

print('*'*100)
print('calculating the result of lcn(tensor)[3][6][6] by hand.')
ls = [tensor[3][i][j] for i in [5, 6, 7] for j in [5, 6, 7]]
print("the values around tensor[3][6][6] is {}".format(ls))
print("the average is {}".format(np.average(ls)))
print("the Euclidean norm is {} > 1".format(np.sqrt(np.sum(np.square(ls)))))
print("Thus the resulting value of lcn(tensor)[3][6][6] must be {} and the result is {}".format(np.average(ls)/np.sqrt(np.sum(np.square(ls))), lcn(tensor)[3][6][6]))
# Out:
# ****************************************************************************************************
# calculating the result of lcn(tensor)[0][3][3] by hand.
# the values around tensor[0][3][3] is [0.054999999701976776, 0.057500001043081284, 0.05999999865889549, 0.07999999821186066, 0.08250000327825546, 0.08500000089406967, 0.10499999672174454, 0.10750000178813934, 0.10999999940395355]
# the average is 0.08249999996688631
# the Euclidean norm is 0.2550367618558687 < 1
# Thus the resulting value of lcn(tensor)[0][3][3] must be 0.08249999996688631 and the result is 0.08250000327825546
# ****************************************************************************************************
# calculating the result of lcn(tensor)[3][6][6] by hand.
# the values around tensor[3][6][6] is [0.887499988079071, 0.8899999856948853, 0.8924999833106995, 0.9125000238418579, 0.9150000214576721, 0.9175000190734863, 0.9375, 0.9399999976158142, 0.9424999952316284]
# the average is 0.9150000015894572
# the Euclidean norm is 2.745689809118098 > 1
# Thus the resulting value of lcn(tensor)[3][6][6] must be 0.33324958942953237 and the result is 0.333249568939209

# %%
tensor[3]
# Out:
#  0.7500  0.7525  0.7550  0.7575  0.7600  0.7625  0.7650  0.7675  0.7700  0.7725
#  0.7750  0.7775  0.7800  0.7825  0.7850  0.7875  0.7900  0.7925  0.7950  0.7975
#  0.8000  0.8025  0.8050  0.8075  0.8100  0.8125  0.8150  0.8175  0.8200  0.8225
#  0.8250  0.8275  0.8300  0.8325  0.8350  0.8375  0.8400  0.8425  0.8450  0.8475
#  0.8500  0.8525  0.8550  0.8575  0.8600  0.8625  0.8650  0.8675  0.8700  0.8725
#  0.8750  0.8775  0.8800  0.8825  0.8850  0.8875  0.8900  0.8925  0.8950  0.8975
#  0.9000  0.9025  0.9050  0.9075  0.9100  0.9125  0.9150  0.9175  0.9200  0.9225
#  0.9250  0.9275  0.9300  0.9325  0.9350  0.9375  0.9400  0.9425  0.9450  0.9475
#  0.9500  0.9525  0.9550  0.9575  0.9600  0.9625  0.9650  0.9675  0.9700  0.9725
#  0.9750  0.9775  0.9800  0.9825  0.9850  0.9875  0.9900  0.9925  0.9950  0.9975
# [torch.FloatTensor of size 10x10]

# %%
lcn(tensor)[0]
# Out:
#  0.0061  0.0100  0.0117  0.0133  0.0150  0.0167  0.0183  0.0200  0.0217  0.0150
#  0.0175  0.0275  0.0300  0.0325  0.0350  0.0375  0.0400  0.0425  0.0450  0.0308
#  0.0342  0.0525  0.0550  0.0575  0.0600  0.0625  0.0650  0.0675  0.0700  0.0475
#  0.0508  0.0775  0.0800  0.0825  0.0850  0.0875  0.0900  0.0925  0.0950  0.0642
#  0.0675  0.1025  0.1050  0.1075  0.1100  0.1125  0.1150  0.1175  0.1200  0.0808
#  0.0842  0.1275  0.1300  0.1325  0.1350  0.1375  0.1400  0.1425  0.1450  0.0975
#  0.1008  0.1525  0.1550  0.1575  0.1600  0.1625  0.1650  0.1675  0.1700  0.1142
#  0.1175  0.1775  0.1800  0.1825  0.1850  0.1875  0.1900  0.1925  0.1950  0.1308
#  0.1342  0.2025  0.2050  0.2075  0.2100  0.2125  0.2150  0.2175  0.2200  0.1475
#  0.0950  0.1433  0.1450  0.1467  0.1483  0.1500  0.1517  0.1533  0.1550  0.1039
# [torch.FloatTensor of size 10x10]

# %%
im = Image.open('./2017-12-16-09-47-27-1200x800.jpg')

# %%
tensor = torchvision.transforms.ToTensor()(im)

# %%
lcned_tensor = lcn(tensor)

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x800 at 0x7F6487114CC0>

# %%
torchvision.transforms.ToPILImage()(lcned_tensor)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800 at 0x7F64870F7898>
